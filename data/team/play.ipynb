# %%
from nba_api.stats.static import teams

nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
celtics = [team for team in nba_teams if team['abbreviation'] == 'BOS'][0]
celtics_id = celtics['id']

# %%
from nba_api.stats.endpoints import leaguegamefinder

# %%
# Query for games where the Celtics were playing
gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable='2023-24') # first season to select data from
# The first DataFrame of those returned is what we want.
games = gamefinder.get_data_frames()[0]

# generate some info about games: 

print("Shape: {}".format(games.shape)) # Number of games played

print("Stats tracked: {}".format(games.columns)) # Stats tracked
# Out:
# Shape: (2899, 28)
# Stats tracked: Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %%
print(games.isna().sum()) # Where gaps in data exist
# Out:
# SEASON_ID            0
# TEAM_ID              0
# TEAM_ABBREVIATION    0
# TEAM_NAME            0
# GAME_ID              0
# GAME_DATE            0
# MATCHUP              0
# WL                   1
# MIN                  0
# PTS                  0
# FGM                  0
# FGA                  0
# FG_PCT               1
# FG3M                 0
# FG3A                 0
# FG3_PCT              1
# FTM                  0
# FTA                  0
# FT_PCT               4
# OREB                 0
# DREB                 0
# REB                  0
# AST                  0
# STL                  0
# BLK                  0
# TOV                  0
# PF                   0
# PLUS_MINUS           0
# dtype: int64

# %%
print(games['SEASON_ID'].value_counts()) # Number of seasons + subseasons in the data
# Out:
# SEASON_ID
# 22023    2234
# 52023     498
# 12023     151
# 32023      14
# 62023       2
# Name: count, dtype: int64

# %%
games.head() # First few rows of the data; games are mirrored from each team's perspective
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION             TEAM_NAME     GAME_ID  \
# 0     32023  1612709974               GIR    Team Giraffe Stars  2032300001
# 1     32023  1612709971               STR    Team StrictlyBball  2032300002
# 2     32023  1612709973               BIL       Team BallisLife  2032300001
# 3     32023  1612709973               BIL       Team BallisLife  2032300003
# 4     32023  1612709972               EYL  Team EarnYourLeisure  2032300002
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  2024-02-18    GIR @ BIL  L   41   25  ...     NaN     4     3    7    3
# 1  2024-02-18  STR vs. EYL  L   67   27  ...     1.0     9    11   20    6
# 2  2024-02-18  BIL vs. GIR  W   41   32  ...     1.0     3     4    7    8
# 3  2024-02-18  BIL vs. EYL  L   49   21  ...     NaN     3     5    8    5
# 4  2024-02-18    EYL @ STR  W   66   30  ...     1.0     3    11   14    7
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# 0    0    1    0   2        -7.0
# 1    2    0    5   2        -3.0
# 2    0    0    0   0         7.0
# 3    1    0    6   4        -9.0
# 4    4    2    3   3         3.0
#
# [5 rows x 28 columns]

# %%
games['MATCHUP'] # Determines whether the team is at home or not via the '@' or 'vs.' symbol
# Out:
# 0         GIR @ BIL
# 1       STR vs. EYL
# 2       BIL vs. GIR
# 3       BIL vs. EYL
# 4         EYL @ STR
#            ...
# 2894    GLI vs. PER
# 2895      PER @ GLI
# 2896    GLI vs. PER
# 2897      PUR @ USA
# 2898    USA vs. PUR
# Name: MATCHUP, Length: 2899, dtype: object

# %%
nba_teams = teams.get_teams()

nba_teams = teams.get_teams()
# Select the dictionary for the Celtics, which contains their team ID
spurs = [team for team in nba_teams if team['abbreviation'] == 'SAS'][0]
spurs_id = spurs['id']

# %%
gamefinder_spurs = leaguegamefinder.LeagueGameFinder(team_id_nullable = [spurs_id])
games_spurs = gamefinder_spurs.get_data_frames()[0]
print(games_spurs.shape)
games_spurs.head()
# Out:
# (3832, 28)
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME     GAME_ID  \
# 0     22023  1610612759               SAS  San Antonio Spurs  0022300785
# 1     22023  1610612759               SAS  San Antonio Spurs  0022300764
# 2     22023  1610612759               SAS  San Antonio Spurs  0022300750
# 3     22023  1610612759               SAS  San Antonio Spurs  0022300734
# 4     22023  1610612759               SAS  San Antonio Spurs  0022300730
#
#     GAME_DATE    MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  STL  \
# 0  2024-02-14  SAS @ DAL  L  239   93  ...   0.733    13    31   44   29    8
# 1  2024-02-12  SAS @ TOR  W  239  122  ...   0.826     5    41   46   37   12
# 2  2024-02-10  SAS @ BKN  L  240  103  ...   0.952    15    26   41   20    5
# 3  2024-02-08  SAS @ ORL  L  239  111  ...   0.941     4    23   27   29    7
# 4  2024-02-07  SAS @ MIA  L  240  104  ...   0.588     6    40   46   30    6
#
#    BLK  TOV  PF  PLUS_MINUS
# 0    7   11   9       -23.0
# 1   13   17  14        23.0
# 2    3   14  11       -20.0
# 3    5   14  16       -16.0
# 4    2   14  21       -12.0
#
# [5 rows x 28 columns]

# %%
games_spurs['SEASON_ID'].value_counts() # select seasons that start with '2'
# Out:
# SEASON_ID
# 22015    92
# 22016    90
# 22018    90
# 22021    90
# 22017    90
#          ..
# 41987     3
# 41985     3
# 12011     2
# 52020     1
# 52021     1
# Name: count, Length: 95, dtype: int64

# %%
games_spurs = games_spurs[games_spurs['SEASON_ID'] == '22015'].head(82) # take regular season games
games_spurs.head()
# Out:
#     SEASON_ID     TEAM_ID TEAM_ABBREVIATION          TEAM_NAME     GAME_ID  \
# 742     22015  1610612759               SAS  San Antonio Spurs  0021501223
# 743     22015  1610612759               SAS  San Antonio Spurs  0021501215
# 744     22015  1610612759               SAS  San Antonio Spurs  0021501201
# 745     22015  1610612759               SAS  San Antonio Spurs  0021501186
# 746     22015  1610612759               SAS  San Antonio Spurs  0021501177
#
#       GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 742  2016-04-13    SAS @ DAL  W  240   96  ...   0.769     8    34   42   24
# 743  2016-04-12  SAS vs. OKC  W  264  102  ...   0.750    11    31   42   15
# 744  2016-04-10  SAS vs. GSW  L  239   86  ...   0.789    18    35   53   21
# 745  2016-04-08    SAS @ DEN  L  240   98  ...   0.821     8    37   45   20
# 746  2016-04-07    SAS @ GSW  L  241  101  ...   0.696     5    27   32   28
#
#      STL  BLK  TOV  PF  PLUS_MINUS
# 742    8    3   14  19         5.0
# 743   12    8   11  22         4.0
# 744   10    5   11  18        -6.0
# 745    6    8   10  12        -4.0
# 746   10    2   12  11       -11.0
#
# [5 rows x 28 columns]

# %%
import numpy as np
import pandas as pd

# %%
raw_df = pd.read_csv('raw/raw.csv')

# %%
print(raw_df.shape)
raw_df.head()
# Out:
# (92430, 28)
#    SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME   GAME_ID  \
# 0      21983  1610612744               GOS  Golden State Warriors  28300938
# 1      21983  1610612759               SAN      San Antonio Spurs  28300943
# 2      21983  1610612738               BOS         Boston Celtics  28300941
# 3      21983  1610612742               DAL       Dallas Mavericks  28300938
# 4      21983  1610612751               NJN        New Jersey Nets  28300941
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB  REB  AST  \
# 0  1984-04-15  GOS vs. DAL  W  240   98  ...   0.571  21.0  29.0   50   20
# 1  1984-04-15  SAN vs. DEN  W  240  157  ...   0.735  10.0  38.0   48   50
# 2  1984-04-15  BOS vs. NJN  W  240  118  ...   0.840  13.0  37.0   50   31
# 3  1984-04-15    DAL @ GOS  L  240   96  ...   0.625  19.0  24.0   43   17
# 4  1984-04-15    NJN @ BOS  L  240  111  ...   0.632  13.0  25.0   38   26
#
#     STL  BLK  TOV  PF  PLUS_MINUS
# 0  14.0    4   24  19         NaN
# 1   8.0    8   18  21         NaN
# 2   8.0    6   17  17         NaN
# 3   8.0    0   24  18         NaN
# 4  11.0    3   14  22         NaN
#
# [5 rows x 28 columns]

# %%
print(raw_df[raw_df['SEASON_ID'].astype(str).str.startswith('2')].shape)
raw_df[raw_df['SEASON_ID'].astype(str).str.startswith('2')]
# Out:
# (92430, 28)
#        SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0          21983  1610612744               GOS  Golden State Warriors
# 1          21983  1610612759               SAN      San Antonio Spurs
# 2          21983  1610612738               BOS         Boston Celtics
# 3          21983  1610612742               DAL       Dallas Mavericks
# 4          21983  1610612751               NJN        New Jersey Nets
# ...          ...         ...               ...                    ...
# 92425      22023  1610612741               CHI          Chicago Bulls
# 92426      22023  1610612744               GSW  Golden State Warriors
# 92427      22023  1610612747               LAL     Los Angeles Lakers
# 92428      22023  1610612743               DEN         Denver Nuggets
# 92429      22023  1610612756               PHX           Phoenix Suns
#
#         GAME_ID   GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  \
# 0      28300938  1984-04-15  GOS vs. DAL  W  240   98  ...   0.571  21.0
# 1      28300943  1984-04-15  SAN vs. DEN  W  240  157  ...   0.735  10.0
# 2      28300941  1984-04-15  BOS vs. NJN  W  240  118  ...   0.840  13.0
# 3      28300938  1984-04-15    DAL @ GOS  L  240   96  ...   0.625  19.0
# 4      28300941  1984-04-15    NJN @ BOS  L  240  111  ...   0.632  13.0
# ...         ...         ...          ... ..  ...  ...  ...     ...   ...
# 92425  22300070  2023-10-25  CHI vs. OKC  L  242  104  ...   0.778  13.0
# 92426  22300062  2023-10-24  GSW vs. PHX  L  240  104  ...   0.786  18.0
# 92427  22300061  2023-10-24    LAL @ DEN  L  239  107  ...   0.750  13.0
# 92428  22300061  2023-10-24  DEN vs. LAL  W  240  119  ...   0.750   9.0
# 92429  22300062  2023-10-24    PHX @ GSW  W  241  108  ...   0.765  17.0
#
#        DREB  REB  AST   STL  BLK  TOV  PF  PLUS_MINUS
# 0      29.0   50   20  14.0    4   24  19         NaN
# 1      38.0   48   50   8.0    8   18  21         NaN
# 2      37.0   50   31   8.0    6   17  17         NaN
# 3      24.0   43   17   8.0    0   24  18         NaN
# 4      25.0   38   26  11.0    3   14  22         NaN
# ...     ...  ...  ...   ...  ...  ...  ..         ...
# 92425  29.0   42   26  10.0    3   12  16       -20.0
# 92426  31.0   49   19  11.0    6   11  23        -4.0
# 92427  31.0   44   23   5.0    4   11  18       -12.0
# 92428  33.0   42   29   9.0    6   11  15        12.0
# 92429  43.0   60   23   5.0    7   19  22         4.0
#
# [92430 rows x 28 columns]

# %%
raw_df[raw_df['SEASON_ID'] == 22022].value_counts('TEAM_ID') # assert regular season
# Out:
# TEAM_ID
# 1610612737    82
# 1610612738    82
# 1610612765    82
# 1610612764    82
# 1610612763    82
# 1610612762    82
# 1610612761    82
# 1610612760    82
# 1610612759    82
# 1610612758    82
# 1610612757    82
# 1610612756    82
# 1610612755    82
# 1610612754    82
# 1610612753    82
# 1610612752    82
# 1610612751    82
# 1610612750    82
# 1610612749    82
# 1610612748    82
# 1610612747    82
# 1610612746    82
# 1610612745    82
# 1610612744    82
# 1610612743    82
# 1610612742    82
# 1610612741    82
# 1610612740    82
# 1610612739    82
# 1610612766    82
# Name: count, dtype: int64

# %%
raw_df.columns
# Out:
# Index(['SEASON_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_NAME', 'GAME_ID',
#        'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'PTS', 'FGM', 'FGA', 'FG_PCT',
#        'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB',
#        'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PLUS_MINUS'],
#       dtype='object')

# %% [markdown]
# Are redundant columns. Keeping them for time being.
#
# CHECKING THAT DATA WAS CLEANED WELL

# %% [markdown]
# STREAKING

# %%
streak_df = pd.read_csv('opped/standardized_0.csv', index_col=0)
#streak_df_scaled = pd.read_csv('processed/scaled/streak.csv')
print(streak_df.shape)
#print(streak_df_scaled.shape)
# Out:
# (92430, 96)

# %%
streak_df.columns
# Out:
# Index(['TEAM_ID_for_prev_0', 'WL_for_prev_0', 'MIN_for_prev_0',
#        'PTS_for_prev_0', 'FGM_for_prev_0', 'FGA_for_prev_0',
#        'FG_PCT_for_prev_0', 'FG3M_for_prev_0', 'FG3A_for_prev_0',
#        'FG3_PCT_for_prev_0', 'FTM_for_prev_0', 'FTA_for_prev_0',
#        'FT_PCT_for_prev_0', 'OREB_for_prev_0', 'DREB_for_prev_0',
#        'REB_for_prev_0', 'AST_for_prev_0', 'STL_for_prev_0', 'BLK_for_prev_0',
#        'TOV_for_prev_0', 'PF_for_prev_0', 'PLUS_MINUS_for_prev_0',
#        'IS_HOME_for_prev_0', 'TEAM_ID_against_prev_0', 'WL_against_prev_0',
#        'MIN_against_prev_0', 'PTS_against_prev_0', 'FGM_against_prev_0',
#        'FGA_against_prev_0', 'FG_PCT_against_prev_0', 'FG3M_against_prev_0',
#        'FG3A_against_prev_0', 'FG3_PCT_against_prev_0', 'FTM_against_prev_0',
#        'FTA_against_prev_0', 'FT_PCT_against_prev_0', 'OREB_against_prev_0',
#        'DREB_against_prev_0', 'REB_against_prev_0', 'AST_against_prev_0',
#        'STL_against_prev_0', 'BLK_against_prev_0', 'TOV_against_prev_0',
#        'PF_against_prev_0', 'PLUS_MINUS_against_prev_0',
#        'IS_HOME_against_prev_0', 'GAME_ID_prev_0', 'k_length',
#        'TEAM_ID_for_prev_0_opp', 'WL_for_prev_0_opp', 'MIN_for_prev_0_opp',
#        'PTS_for_prev_0_opp', 'FGM_for_prev_0_opp', 'FGA_for_prev_0_opp',
#        'FG_PCT_for_prev_0_opp', 'FG3M_for_prev_0_opp', 'FG3A_for_prev_0_opp',
#        'FG3_PCT_for_prev_0_opp', 'FTM_for_prev_0_opp', 'FTA_for_prev_0_opp',
#        'FT_PCT_for_prev_0_opp', 'OREB_for_prev_0_opp', 'DREB_for_prev_0_opp',
#        'REB_for_prev_0_opp', 'AST_for_prev_0_opp', 'STL_for_prev_0_opp',
#        'BLK_for_prev_0_opp', 'TOV_for_prev_0_opp', 'PF_for_prev_0_opp',
#        'PLUS_MINUS_for_prev_0_opp', 'IS_HOME_for_prev_0_opp',
#        'TEAM_ID_against_prev_0_opp', 'WL_against_prev_0_opp',
#        'MIN_against_prev_0_opp', 'PTS_against_prev_0_opp',
#        'FGM_against_prev_0_opp', 'FGA_against_prev_0_opp',
#        'FG_PCT_against_prev_0_opp', 'FG3M_against_prev_0_opp',
#        'FG3A_against_prev_0_opp', 'FG3_PCT_against_prev_0_opp',
#        'FTM_against_prev_0_opp', 'FTA_against_prev_0_opp',
#        'FT_PCT_against_prev_0_opp', 'OREB_against_prev_0_opp',
#        'DREB_against_prev_0_opp', 'REB_against_prev_0_opp',
#        'AST_against_prev_0_opp', 'STL_against_prev_0_opp',
#        'BLK_against_prev_0_opp', 'TOV_against_prev_0_opp',
#        'PF_against_prev_0_opp', 'PLUS_MINUS_against_prev_0_opp',
#        'IS_HOME_against_prev_0_opp', 'GAME_ID_prev_0_opp', 'k_length_opp'],
#       dtype='object')

# %%
streak_df.head()
# Out:
#           TEAM_ID_for_prev_0  WL_for_prev_0  MIN_for_prev_0  PTS_for_prev_0  \
# ID
# 40000002                 NaN            NaN             NaN             NaN
# 40000003                 NaN            NaN             NaN             NaN
# 40000004                 NaN            NaN             NaN             NaN
# 40000005                 NaN            NaN             NaN             NaN
# 40000006                 NaN            NaN             NaN             NaN
#
#           FGM_for_prev_0  FGA_for_prev_0  FG_PCT_for_prev_0  FG3M_for_prev_0  \
# ID
# 40000002             NaN             NaN                NaN              NaN
# 40000003             NaN             NaN                NaN              NaN
# 40000004             NaN             NaN                NaN              NaN
# 40000005             NaN             NaN                NaN              NaN
# 40000006             NaN             NaN                NaN              NaN
#
#           FG3A_for_prev_0  FG3_PCT_for_prev_0  ...  REB_against_prev_0_opp  \
# ID                                             ...
# 40000002              NaN                 NaN  ...                     NaN
# 40000003              NaN                 NaN  ...                     NaN
# 40000004              NaN                 NaN  ...                     NaN
# 40000005              NaN                 NaN  ...                     NaN
# 40000006              NaN                 NaN  ...                     NaN
#
#           AST_against_prev_0_opp  STL_against_prev_0_opp  \
# ID
# 40000002                     NaN                     NaN
# 40000003                     NaN                     NaN
# 40000004                     NaN                     NaN
# 40000005                     NaN                     NaN
# 40000006                     NaN                     NaN
#
#           BLK_against_prev_0_opp  TOV_against_prev_0_opp  \
# ID
# 40000002                     NaN                     NaN
# 40000003                     NaN                     NaN
# 40000004                     NaN                     NaN
# 40000005                     NaN                     NaN
# 40000006                     NaN                     NaN
#
#           PF_against_prev_0_opp  PLUS_MINUS_against_prev_0_opp  \
# ID
# 40000002                    NaN                            NaN
# 40000003                    NaN                            NaN
# 40000004                    NaN                            NaN
# 40000005                    NaN                            NaN
# 40000006                    NaN                            NaN
#
#           IS_HOME_against_prev_0_opp  GAME_ID_prev_0_opp  k_length_opp
# ID
# 40000002                         NaN                 NaN           0.0
# 40000003                         NaN                 NaN           0.0
# 40000004                         NaN                 NaN           0.0
# 40000005                         NaN                 NaN           0.0
# 40000006                         NaN                 NaN           0.0
#
# [5 rows x 96 columns]

# %%
# Data sanity check
idx = 2000
# Assert first team's stats are in line
print(streak_df.iloc[idx]['WL_for_prev_0'])
print(streak_df.iloc[idx+1]['WL_for_prev_0_opp'])
print(streak_df.iloc[idx]['WL_against_prev_0'])
print(streak_df.iloc[idx+1]['WL_against_prev_0_opp'])

# Assert second team's stats are in line
print(streak_df.iloc[idx]['WL_for_prev_0_opp'])
print(streak_df.iloc[idx+1]['WL_for_prev_0'])
print(streak_df.iloc[idx]['WL_against_prev_0_opp'])
print(streak_df.iloc[idx+1]['WL_against_prev_0'])
# Out:
# 0.6865671641791045
# 0.6865671641791045
# 0.3134328358208955
# 0.3134328358208955
# 0.2463768115942029
# 0.2463768115942029
# 0.7536231884057971
# 0.7536231884057971

# %%
corrs = streak_df.corr()

# %%
cols_0 = [col for col in streak_df.columns if "_0" in col]
corrs.loc[cols_0, "WL_for_A"].sort_values(ascending=False)
# Out:
# PLUS_MINUS_for_prev_0_A        0.231322
# PLUS_MINUS_against_prev_0_B    0.231314
# WL_for_prev_0_A                0.219506
# WL_against_prev_0_B            0.219506
# FG_PCT_for_prev_0_A            0.147263
#                                  ...
# FG_PCT_for_prev_0_B           -0.147263
# WL_against_prev_0_A           -0.219506
# WL_for_prev_0_B               -0.219506
# PLUS_MINUS_against_prev_0_A   -0.231314
# PLUS_MINUS_for_prev_0_B       -0.231322
# Name: WL_for_A, Length: 94, dtype: float64

# %% [markdown]
# PREVIOUSLY USED FEATURES

# %%
# All features being used

# Old features
WL = ['WL_for_prev_0_A', 'WL_for_prev_0_B']
AST = ['AST_for_prev_0_A', 'AST_against_prev_0_A', 'AST_for_prev_0_B', 'AST_against_prev_0_B']
REB = ['REB_for_prev_0_A', 'REB_against_prev_0_A', 'REB_for_prev_0_B', 'REB_against_prev_0_B']
FG_PCT = ['FG_PCT_for_prev_0_A', 'FG_PCT_against_prev_0_A', 'FG_PCT_for_prev_0_B', 'FG_PCT_against_prev_0_B']
FG3_PCT = ['FG3_PCT_for_prev_0_A', 'FG3_PCT_against_prev_0_A', 'FG3_PCT_for_prev_0_B', 'FG3_PCT_against_prev_0_B']
PTS = ['PTS_for_prev_0_A', 'PTS_against_prev_0_A', 'PTS_for_prev_0_B', 'PTS_against_prev_0_B']
old_features = WL + AST + REB + FG_PCT + FG3_PCT + PTS


# New features
PLUS_MINUS = ['PLUS_MINUS_for_prev_0_A', 'PLUS_MINUS_for_prev_0_B']
BLK = ['BLK_for_prev_0_A', 'BLK_against_prev_0_A', 'BLK_for_prev_0_B', 'BLK_against_prev_0_B']
STL = ['STL_for_prev_0_A', 'STL_against_prev_0_A', 'STL_for_prev_0_B', 'STL_against_prev_0_B']
TOV = ['TOV_for_prev_0_A', 'TOV_against_prev_0_A', 'TOV_for_prev_0_B', 'TOV_against_prev_0_B']
PF = ['PF_for_prev_0_A', 'PF_against_prev_0_A', 'PF_for_prev_0_B', 'PF_against_prev_0_B']
MIN = ['MIN_for_prev_0_A', 'MIN_for_prev_0_B']
OREB = ['OREB_for_prev_0_A', 'OREB_against_prev_0_A', 'OREB_for_prev_0_B', 'OREB_against_prev_0_B']
DREB = ['DREB_for_prev_0_A', 'DREB_against_prev_0_A', 'DREB_for_prev_0_B', 'DREB_against_prev_0_B']
new_features1 = PLUS_MINUS + BLK + STL + TOV + PF + MIN + OREB + DREB


FGM = ['FGM_for_prev_0_A', 'FGM_against_prev_0_A', 'FGM_for_prev_0_B', 'FGM_against_prev_0_B']
FGA = ['FGA_for_prev_0_A', 'FGA_against_prev_0_A', 'FGA_for_prev_0_B', 'FGA_against_prev_0_B']
FG3M = ['FG3M_for_prev_0_A', 'FG3M_against_prev_0_A', 'FG3M_for_prev_0_B', 'FG3M_against_prev_0_B']
FG3A = ['FG3A_for_prev_0_A', 'FG3A_against_prev_0_A', 'FG3A_for_prev_0_B', 'FG3A_against_prev_0_B']
FTM = ['FTM_for_prev_0_A', 'FTM_against_prev_0_A', 'FTM_for_prev_0_B', 'FTM_against_prev_0_B']
FTA = ['FTA_for_prev_0_A', 'FTA_against_prev_0_A', 'FTA_for_prev_0_B', 'FTA_against_prev_0_B']
FT_PCT = ['FT_PCT_for_prev_0_A', 'FT_PCT_against_prev_0_A', 'FT_PCT_for_prev_0_B', 'FT_PCT_against_prev_0_B']
new_features2 = FGM + FGA + FG3M + FG3A + FTM + FTA + FT_PCT

IS_HOME = ['IS_HOME_for_prev_0_A', 'IS_HOME_for_prev_0_B',
                    'IS_HOME_against_prev_0_A', 'IS_HOME_against_prev_0_B',
                    'IS_HOME_for_A', 'IS_HOME_for_B',
                    'IS_HOME_against_A', 'IS_HOME_against_B']

# %%
# WL, FG_PCT, FG3_PCT, AST, REB
corrs.loc[old_features, "WL_for_A"].sort_values(ascending=False)
# Out:
# WL_for_prev_0_A             0.219506
# FG_PCT_for_prev_0_A         0.147263
# FG_PCT_against_prev_0_B     0.131924
# PTS_for_prev_0_A            0.128263
# PTS_against_prev_0_B        0.122811
# AST_for_prev_0_A            0.108360
# AST_against_prev_0_B        0.107731
# REB_against_prev_0_B        0.095808
# FG3_PCT_for_prev_0_A        0.083278
# REB_for_prev_0_A            0.058441
# FG3_PCT_against_prev_0_B    0.043072
# FG3_PCT_against_prev_0_A   -0.043072
# REB_for_prev_0_B           -0.058441
# FG3_PCT_for_prev_0_B       -0.083278
# REB_against_prev_0_A       -0.095808
# AST_against_prev_0_A       -0.107731
# AST_for_prev_0_B           -0.108360
# PTS_against_prev_0_A       -0.122811
# PTS_for_prev_0_B           -0.128263
# FG_PCT_against_prev_0_A    -0.131924
# FG_PCT_for_prev_0_B        -0.147263
# WL_for_prev_0_B            -0.219506
# Name: WL_for_A, dtype: float64

# %% [markdown]
# NEWLY USED FEATURES

# %%
# STL, BLK, TOV, PF, MIN, PLUS_MINUS
corrs.loc[new_features1, "WL_for_A"].sort_values(ascending=False)
# Out:
# PLUS_MINUS_for_prev_0_A    0.231322
# BLK_against_prev_0_B       0.114797
# DREB_for_prev_0_A          0.106502
# DREB_against_prev_0_B      0.103734
# STL_against_prev_0_B       0.070238
# TOV_for_prev_0_B           0.069463
# PF_for_prev_0_B            0.059299
# BLK_for_prev_0_A           0.045831
# PF_against_prev_0_A        0.040458
# OREB_for_prev_0_B          0.040034
# STL_for_prev_0_A           0.030303
# OREB_against_prev_0_B      0.029075
# TOV_against_prev_0_B       0.004576
# MIN_for_prev_0_A           0.001043
# MIN_for_prev_0_B          -0.001043
# TOV_against_prev_0_A      -0.004576
# OREB_against_prev_0_A     -0.029075
# STL_for_prev_0_B          -0.030303
# OREB_for_prev_0_A         -0.040034
# PF_against_prev_0_B       -0.040458
# BLK_for_prev_0_B          -0.045831
# PF_for_prev_0_A           -0.059299
# TOV_for_prev_0_A          -0.069463
# STL_against_prev_0_A      -0.070238
# DREB_against_prev_0_A     -0.103734
# DREB_for_prev_0_B         -0.106502
# BLK_against_prev_0_A      -0.114797
# PLUS_MINUS_for_prev_0_B   -0.231322
# Name: WL_for_A, dtype: float64

# %%
# FGM, FGA, FG3M, FG3A, FTM, FTA, FT_PCT, OREB, DREB
# These are the features that aren't being used well
corrs.loc[new_features2, "WL_for_A"].sort_values(ascending=False)
# Out:
# FGM_for_prev_0_A           0.100241
# FGM_against_prev_0_B       0.096436
# FG3M_for_prev_0_A          0.083294
# FTM_against_prev_0_B       0.068639
# FTA_against_prev_0_B       0.068344
# FG3A_for_prev_0_A          0.059449
# FTM_for_prev_0_A           0.054578
# FT_PCT_for_prev_0_A        0.048565
# FTA_for_prev_0_A           0.039441
# FGA_for_prev_0_B           0.030671
# FG3M_against_prev_0_B      0.021125
# FG3A_against_prev_0_A      0.009581
# FT_PCT_against_prev_0_B    0.009397
# FGA_against_prev_0_B       0.000562
# FGA_against_prev_0_A      -0.000562
# FT_PCT_against_prev_0_A   -0.009397
# FG3A_against_prev_0_B     -0.009581
# FG3M_against_prev_0_A     -0.021125
# FGA_for_prev_0_A          -0.030671
# FTA_for_prev_0_B          -0.039441
# FT_PCT_for_prev_0_B       -0.048565
# FTM_for_prev_0_B          -0.054578
# FG3A_for_prev_0_B         -0.059449
# FTA_against_prev_0_A      -0.068344
# FTM_against_prev_0_A      -0.068639
# FG3M_for_prev_0_B         -0.083294
# FGM_against_prev_0_A      -0.096436
# FGM_for_prev_0_B          -0.100241
# Name: WL_for_A, dtype: float64

# %%
# IS_HOME features
corrs.loc[IS_HOME, "WL_for_A"].sort_values(ascending=False)
# Out:
# IS_HOME_for_A               0.209815
# IS_HOME_against_B           0.209815
# IS_HOME_against_prev_0_A    0.025750
# IS_HOME_for_prev_0_B        0.025750
# IS_HOME_against_prev_0_B   -0.025750
# IS_HOME_for_prev_0_A       -0.025750
# IS_HOME_for_B              -0.209815
# IS_HOME_against_A          -0.209815
# Name: WL_for_A, dtype: float64

# %% [markdown]
# Sick correlations ... features with highest correlations:
# * IS_HOME (.20)
# * WL (.22)
# * PLUS_MINUS (.23)
# * FG_PCT (.13)
# * BLK (.1)

# %%
best_features = IS_HOME + PLUS_MINUS + WL + FG_PCT + BLK

# %% [markdown]
# Finding best features via random forest (?)

# %% [markdown]
# BUILDING MODEL

# %%
# imports 
# IMPORTS
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import confusion_matrix

# %%
# features being used
features = old_features + new_features1 + new_features2 + IS_HOME
# features = best_features

print("Features used:")

# Use either streak_df or streak_df_scaled
data_used = streak_df.dropna().copy()

X_raw = data_used[features].copy() # need to figure out how to handle NaN's
print(X_raw.columns)
y = data_used["WL_for_A"].copy()
# Out:
# Features used:
# Index(['WL_for_prev_0_A', 'WL_for_prev_0_B', 'AST_for_prev_0_A',
#        'AST_against_prev_0_A', 'AST_for_prev_0_B', 'AST_against_prev_0_B',
#        'REB_for_prev_0_A', 'REB_against_prev_0_A', 'REB_for_prev_0_B',
#        'REB_against_prev_0_B', 'FG_PCT_for_prev_0_A',
#        'FG_PCT_against_prev_0_A', 'FG_PCT_for_prev_0_B',
#        'FG_PCT_against_prev_0_B', 'FG3_PCT_for_prev_0_A',
#        'FG3_PCT_against_prev_0_A', 'FG3_PCT_for_prev_0_B',
#        'FG3_PCT_against_prev_0_B', 'PTS_for_prev_0_A', 'PTS_against_prev_0_A',
#        'PTS_for_prev_0_B', 'PTS_against_prev_0_B', 'PLUS_MINUS_for_prev_0_A',
#        'PLUS_MINUS_for_prev_0_B', 'BLK_for_prev_0_A', 'BLK_against_prev_0_A',
#        'BLK_for_prev_0_B', 'BLK_against_prev_0_B', 'STL_for_prev_0_A',
#        'STL_against_prev_0_A', 'STL_for_prev_0_B', 'STL_against_prev_0_B',
#        'TOV_for_prev_0_A', 'TOV_against_prev_0_A', 'TOV_for_prev_0_B',
#        'TOV_against_prev_0_B', 'PF_for_prev_0_A', 'PF_against_prev_0_A',
#        'PF_for_prev_0_B', 'PF_against_prev_0_B', 'MIN_for_prev_0_A',
#        'MIN_for_prev_0_B', 'OREB_for_prev_0_A', 'OREB_against_prev_0_A',
#        'OREB_for_prev_0_B', 'OREB_against_prev_0_B', 'DREB_for_prev_0_A',
#        'DREB_against_prev_0_A', 'DREB_for_prev_0_B', 'DREB_against_prev_0_B',
#        'FGM_for_prev_0_A', 'FGM_against_prev_0_A', 'FGM_for_prev_0_B',
#        'FGM_against_prev_0_B', 'FGA_for_prev_0_A', 'FGA_against_prev_0_A',
#        'FGA_for_prev_0_B', 'FGA_against_prev_0_B', 'FG3M_for_prev_0_A',
#        'FG3M_against_prev_0_A', 'FG3M_for_prev_0_B', 'FG3M_against_prev_0_B',
#        'FG3A_for_prev_0_A', 'FG3A_against_prev_0_A', 'FG3A_for_prev_0_B',
#        'FG3A_against_prev_0_B', 'FTM_for_prev_0_A', 'FTM_against_prev_0_A',
#        'FTM_for_prev_0_B', 'FTM_against_prev_0_B', 'FTA_for_prev_0_A',
#        'FTA_against_prev_0_A', 'FTA_for_prev_0_B', 'FTA_against_prev_0_B',
#        'FT_PCT_for_prev_0_A', 'FT_PCT_against_prev_0_A', 'FT_PCT_for_prev_0_B',
#        'FT_PCT_against_prev_0_B', 'IS_HOME_for_prev_0_A',
#        'IS_HOME_for_prev_0_B', 'IS_HOME_against_prev_0_A',
#        'IS_HOME_against_prev_0_B', 'IS_HOME_for_A', 'IS_HOME_for_B',
#        'IS_HOME_against_A', 'IS_HOME_against_B'],
#       dtype='object')

# %%
# Changing to np array
X = np.array(X_raw)
y = np.array(y)
X.shape, y.shape
# Out:
# ((89198, 86), (89198,))

# %%
for state in range(0, 10):

    # Splitting data into training and testing data
    print(' * Splitting data ... ')
    X_train, X_test, y_train, y_true = train_test_split(X, y, test_size=0.2, random_state=state)

    # Model training
    print(' * Training model ... ')
    lr_model = LogisticRegression(max_iter=10000, random_state=state)
    lr_model.fit(X_train, y_train)

    # Get training accuracy
    print("Accuracy run {}: ".format(state+1))
    print("Train {:.10f}".format(accuracy_score(lr_model.predict(X_train), y_train)))
    
    # Get test accuracy
    y_logits = lr_model.predict(X_test)
    y_pred = y_logits.round()
    print("Test {:.10f}".format(accuracy_score(y_pred, y_true)))
# Out:
#  * Splitting data ...
#  * Training model ...
# Accuracy run 1:
# Train 0.6738417557
# Test 0.6720291480
#  * Splitting data ...
#  * Training model ...
# Accuracy run 2:
# Train 0.6734353541
# Test 0.6729260090
#  * Splitting data ...
#  * Training model ...
# Accuracy run 3:
# Train 0.6736876034
# Test 0.6714125561
#  * Splitting data ...
#  * Training model ...
# Accuracy run 4:
# Train 0.6725805095
# Test 0.6761210762
#  * Splitting data ...
#  * Training model ...
# Accuracy run 5:
# Train 0.6731831049
# Test 0.6737668161
#  * Splitting data ...
#  * Training model ...
# Accuracy run 6:
# Train 0.6733792987
# Test 0.6742713004
#  * Splitting data ...
#  * Training model ...
# Accuracy run 7:
# Train 0.6730289526
# Test 0.6735986547
#  * Splitting data ...
#  * Training model ...
# Accuracy run 8:
# Train 0.6728607865
# Test 0.6751681614
#  * Splitting data ...
#  * Training model ...
# Accuracy run 9:
# Train 0.6734633818
# Test 0.6712443946
#  * Splitting data ...
#  * Training model ...
# Accuracy run 10:
# Train 0.6729728972
# Test 0.6720291480

# %%
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)
print("Precision: {}".format(precision)) # TP / (TP + FP)
print("Recall: {}".format(recall)) # TP / (TP + FN)
print("F1 Score: {}".format(f1)) # 2 * (precision * recall) / (precision + recall)
# Out:
# Precision: 0.6785754283794377
# Recall: 0.6702433628318584
# F1 Score: 0.6743836607490677

# %% [markdown]
# RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 2
#       1 rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
# ----> 2 rf_classifier.fit(X_train, y_train)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:456, in BaseForest.fit(self, X, y, sample_weight)
#     445 trees = [
#     446     self._make_estimator(append=False, random_state=random_state)
#     447     for i in range(n_more_estimators)
#     448 ]
#     450 # Parallel loop: we prefer the threading backend as the Cython code
#     451 # for fitting the trees is internally releasing the Python GIL
#     452 # making threading more efficient than multiprocessing in
#     453 # that case. However, for joblib 0.12+ we respect any
#     454 # parallel_backend contexts set at a higher level,
#     455 # since correctness does not rely on using threads.
# --> 456 trees = Parallel(
#     457     n_jobs=self.n_jobs,
#     458     verbose=self.verbose,
#     459     prefer="threads",
#     460 )(
#     461     delayed(_parallel_build_trees)(
#     462         t,
#     463         self.bootstrap,
#     464         X,
#     465         y,
#     466         sample_weight,
#     467         i,
#     468         len(trees),
#     469         verbose=self.verbose,
#     470         class_weight=self.class_weight,
#     471         n_samples_bootstrap=n_samples_bootstrap,
#     472     )
#     473     for i, t in enumerate(trees)
#     474 )
#     476 # Collect newly grown trees
#     477 self.estimators_.extend(trees)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/joblib/parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/ensemble/_forest.py:188, in _parallel_build_trees(tree, bootstrap, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     185     elif class_weight == "balanced_subsample":
#     186         curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
# --> 188     tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     189 else:
#     190     tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/tree/_classes.py:959, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     928 @_fit_context(prefer_skip_nested_validation=True)
#     929 def fit(self, X, y, sample_weight=None, check_input=True):
#     930     """Build a decision tree classifier from the training set (X, y).
#     931
#     932     Parameters
#    (...)
#     956         Fitted estimator.
#     957     """
# --> 959     super()._fit(
#     960         X,
#     961         y,
#     962         sample_weight=sample_weight,
#     963         check_input=check_input,
#     964     )
#     965     return self
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/sklearn/tree/_classes.py:443, in BaseDecisionTree._fit(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     432 else:
#     433     builder = BestFirstTreeBuilder(
#     434         splitter,
#     435         min_samples_split,
#    (...)
#     440         self.min_impurity_decrease,
#     441     )
# --> 443 builder.build(self.tree_, X, y, sample_weight, missing_values_in_feature_mask)
#     445 if self.n_outputs_ == 1 and is_classifier(self):
#     446     self.n_classes_ = self.n_classes_[0]
#
# KeyboardInterrupt:

# %%
# Evaluate the model
# Predict on the test set
y_pred = rf_classifier.predict(X_test).round()

accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6411434977578475

# %% [markdown]
# GRADINTBOOSTINGMACHINE

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb_classifier = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
gb_classifier.fit(X_train, y_train)

# Predict on the test set
y_pred = gb_classifier.predict(X_test).round()

# Evaluate the model
accuracy = accuracy_score(y_true, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.6716928251121076

# %% [markdown]
# SVM

# %%
from sklearn.svm import SVC

# %% [markdown]
# Building a LR model such that:
# * training on everything but 2023-24 season data
# * predicting 2023-24 season data

# %%
# features being used
features = old_features + new_features1 + new_features2 + IS_HOME
# features = best_features
features = features + ['SEASON_ID_A', 'GAME_DATE_A']

print("Features used:")

# Use either streak_df or streak_df_scaled
data_used = streak_df.dropna().copy()
data_used['GAME_DATE_A'] = pd.to_datetime(data_used['GAME_DATE_A'])

X_raw = data_used[features].copy() # need to figure out how to handle NaN's
print(X_raw.columns)
y = data_used["WL_for_A"].copy()
# Out:
# Features used:
# Index(['WL_for_prev_0_A', 'WL_for_prev_0_B', 'AST_for_prev_0_A',
#        'AST_against_prev_0_A', 'AST_for_prev_0_B', 'AST_against_prev_0_B',
#        'REB_for_prev_0_A', 'REB_against_prev_0_A', 'REB_for_prev_0_B',
#        'REB_against_prev_0_B', 'FG_PCT_for_prev_0_A',
#        'FG_PCT_against_prev_0_A', 'FG_PCT_for_prev_0_B',
#        'FG_PCT_against_prev_0_B', 'FG3_PCT_for_prev_0_A',
#        'FG3_PCT_against_prev_0_A', 'FG3_PCT_for_prev_0_B',
#        'FG3_PCT_against_prev_0_B', 'PTS_for_prev_0_A', 'PTS_against_prev_0_A',
#        'PTS_for_prev_0_B', 'PTS_against_prev_0_B', 'PLUS_MINUS_for_prev_0_A',
#        'PLUS_MINUS_for_prev_0_B', 'BLK_for_prev_0_A', 'BLK_against_prev_0_A',
#        'BLK_for_prev_0_B', 'BLK_against_prev_0_B', 'STL_for_prev_0_A',
#        'STL_against_prev_0_A', 'STL_for_prev_0_B', 'STL_against_prev_0_B',
#        'TOV_for_prev_0_A', 'TOV_against_prev_0_A', 'TOV_for_prev_0_B',
#        'TOV_against_prev_0_B', 'PF_for_prev_0_A', 'PF_against_prev_0_A',
#        'PF_for_prev_0_B', 'PF_against_prev_0_B', 'MIN_for_prev_0_A',
#        'MIN_for_prev_0_B', 'OREB_for_prev_0_A', 'OREB_against_prev_0_A',
#        'OREB_for_prev_0_B', 'OREB_against_prev_0_B', 'DREB_for_prev_0_A',
#        'DREB_against_prev_0_A', 'DREB_for_prev_0_B', 'DREB_against_prev_0_B',
#        'FGM_for_prev_0_A', 'FGM_against_prev_0_A', 'FGM_for_prev_0_B',
#        'FGM_against_prev_0_B', 'FGA_for_prev_0_A', 'FGA_against_prev_0_A',
#        'FGA_for_prev_0_B', 'FGA_against_prev_0_B', 'FG3M_for_prev_0_A',
#        'FG3M_against_prev_0_A', 'FG3M_for_prev_0_B', 'FG3M_against_prev_0_B',
#        'FG3A_for_prev_0_A', 'FG3A_against_prev_0_A', 'FG3A_for_prev_0_B',
#        'FG3A_against_prev_0_B', 'FTM_for_prev_0_A', 'FTM_against_prev_0_A',
#        'FTM_for_prev_0_B', 'FTM_against_prev_0_B', 'FTA_for_prev_0_A',
#        'FTA_against_prev_0_A', 'FTA_for_prev_0_B', 'FTA_against_prev_0_B',
#        'FT_PCT_for_prev_0_A', 'FT_PCT_against_prev_0_A', 'FT_PCT_for_prev_0_B',
#        'FT_PCT_against_prev_0_B', 'IS_HOME_for_prev_0_A',
#        'IS_HOME_for_prev_0_B', 'IS_HOME_against_prev_0_A',
#        'IS_HOME_against_prev_0_B', 'IS_HOME_for_A', 'IS_HOME_for_B',
#        'IS_HOME_against_A', 'IS_HOME_against_B', 'SEASON_ID_A', 'GAME_DATE_A'],
#       dtype='object')

# %%
seasons_arr = np.arange(2015, 2024, 1)
res = []

for season in seasons_arr:

    # Season to train for
    season += 20000
    recency_bias = 10
    recency_weight = 1

    print(' * Training model data before {} season '.format(season - 20000))
    # Splitting data into training and testing data
    print(' * Splitting data ... ')
    X_train = X_raw[X_raw['SEASON_ID_A'] < season]
    y_train = y[X_raw['SEASON_ID_A'] < season]


    # Identify data in training set
    #cutoff_date = pd.to_datetime('2023-12-31')
    test_cond = (X_raw['SEASON_ID_A'] == season) # & (X_raw['GAME_DATE_A'] > cutoff_date)
    X_test = X_raw[test_cond]
    y_true = y[test_cond]

    print(' * Identifying recent data (past {} seasons)'.format(recency_bias))
    print(' * Counting recent data {} times more in training data'.format(recency_weight))
    # Identify recent data; doesn't select current season
    X_recent = X_train[X_train['SEASON_ID_A'] > season - recency_bias]
    y_recent = y_train[X_train['SEASON_ID_A'] > season - recency_bias]

    # count recent data more in training data
    for i in range(1, recency_weight):
        X_train = pd.concat([X_train, X_recent], axis=0)
        y_train = pd.concat([y_train, y_recent], axis=0)

    X_train = X_train.drop(columns=['SEASON_ID_A', 'GAME_DATE_A'])
    X_test = X_test.drop(columns=['SEASON_ID_A', 'GAME_DATE_A'])



    state = 100

    # Model training
    lr_model = LogisticRegression(max_iter=10000, random_state=state)
    lr_model.fit(X_train, y_train)
    
    #gb_classifier = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, random_state=42)
    #gb_classifier.fit(X_train, y_train)
    
    #svm = SVC(kernel='linear', random_state=state)
    #svm.fit(X_train, y_train)

    # Get training accuracy
    print("Train {:.10f}".format(accuracy_score(lr_model.predict(X_train), y_train)))
        
    # Get test accuracy
    y_logits = lr_model.predict(X_test)
    y_pred = y_logits.round()
    print("Test {:.10f}".format(accuracy_score(y_pred, y_true)))
    res.append(accuracy_score(y_pred, y_true))
# Out:
#  * Training model data before 2015 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6823382507
# Test 0.6784830998
#  * Training model data before 2016 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6822491514
# Test 0.6437397035
#  * Training model data before 2017 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6812928953
# Test 0.6449752883
#  * Training model data before 2018 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6802925651
# Test 0.6470345964
#  * Training model data before 2019 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6787432236
# Test 0.6337488015
#  * Training model data before 2020 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6777036743
# Test 0.6127819549
#  * Training model data before 2021 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6763490990
# Test 0.6144975288
#  * Training model data before 2022 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6749272505
# Test 0.6235584843
#  * Training model data before 2023 season
#  * Splitting data ...
#  * Identifying recent data (past 10 seasons)
#  * Counting recent data 1 times more in training data
# Train 0.6740291151
# Test 0.6481241915

# %%
print(seasons_arr)
res = np.array(res).round(2)
print(res)
print(res.mean())
# Out:
# [2015 2016 2017 2018 2019 2020 2021 2022 2023]
# [0.68 0.64 0.64 0.65 0.63 0.61 0.61 0.62 0.65]
# 0.6366666666666667

# %% [markdown]
# Above tests prove we need to overtrain on more recent data, since we want the model to predict current game outcomes. Prediction accuracy sees a falloff after 2015.
#
# Also worth identifying features that have started to correlate more heavily with wins.

# %% [markdown]
# PLAYING AROUND WITH ELO

# %%
mirror_df = pd.read_csv('processed/standardized/mirror.csv', index_col=0)
mirror_df.head()
# Out:
#           TEAM_ID_for TEAM_ABBREVIATION_for        TEAM_NAME_for  MATCHUP_for  \
# ID
# 40000002   1610612752                   NYK      New York Knicks  NYK vs. PHI
# 40000003   1610612755                   PHI   Philadelphia 76ers    PHI @ NYK
# 40000004   1610612751                   NJN      New Jersey Nets  NJN vs. CLE
# 40000005   1610612739                   CLE  Cleveland Cavaliers    CLE @ NJN
# 40000006   1610612753                   ORL        Orlando Magic  ORL vs. WAS
#
#          WL_for   MIN_for   PTS_for   FGM_for   FGA_for  FG_PCT_for  ...  \
# ID                                                                   ...
# 40000002      L -0.509485 -1.985160 -2.151718 -1.396232   -1.516435  ...
# 40000003      W -0.259500  0.538679  0.465563 -1.923170    2.293229  ...
# 40000004      L -0.384493 -1.114870 -0.943742  0.579787   -1.377269  ...
# 40000005      W -0.259500 -0.766755 -0.742412 -0.342355   -0.594461  ...
# 40000006      W -0.259500  0.190563 -0.339754 -0.210620   -0.246547  ...
#
#           AST_against  STL_against  BLK_against  TOV_against  PF_against  \
# ID
# 40000002     1.028443     0.739005    -0.092453    -0.350397    0.359853
# 40000003    -1.531403    -0.618025    -0.449939     1.902968    1.666644
# 40000004    -1.137581    -0.957282     0.980004     1.151846    1.013249
# 40000005     0.437709     0.399747     0.980004    -0.600771    1.884443
# 40000006    -0.349936    -0.618025    -1.522396     2.904464    1.231047
#
#           PLUS_MINUS_against  IS_HOME_against   GAME_ID   GAME_DATE  SEASON_ID
# ID
# 40000002            2.237111                0  20000001  2000-10-31      22000
# 40000003           -2.236981                1  20000001  2000-10-31      22000
# 40000004            0.308623                0  20000002  2000-10-31      22000
# 40000005           -0.308493                1  20000002  2000-10-31      22000
# 40000006           -0.848470                0  20000003  2000-10-31      22000
#
# [5 rows x 55 columns]

# %%
home_means = mirror_df[mirror_df['IS_HOME_for'] == 1].select_dtypes(include='number').mean()
home_means
# Out:
# TEAM_ID_for           1.610613e+09
# MIN_for              -8.499655e-05
# PTS_for               1.363469e-01
# FGM_for               1.064552e-01
# FGA_for               1.077243e-02
# FG_PCT_for            1.089570e-01
# FG3M_for              1.513854e-02
# FG3A_for             -1.113951e-02
# FG3_PCT_for           3.331437e-02
# FTM_for               7.412581e-02
# FTA_for               7.450784e-02
# FT_PCT_for            1.278262e-02
# OREB_for              5.024425e-02
# DREB_for              1.102162e-01
# REB_for               1.181306e-01
# AST_for               1.670027e-01
# STL_for               2.352643e-02
# BLK_for               1.162435e-01
# TOV_for              -4.774704e-02
# PF_for               -8.331199e-02
# PLUS_MINUS_for        2.538845e-01
# IS_HOME_for           1.000000e+00
# TEAM_ID_against       1.610613e+09
# MIN_against           8.499655e-05
# PTS_against          -1.363469e-01
# FGM_against          -1.064552e-01
# FGA_against          -1.077243e-02
# FG_PCT_against       -1.089570e-01
# FG3M_against         -1.513854e-02
# FG3A_against          1.113951e-02
# FG3_PCT_against      -3.317327e-02
# FTM_against          -7.412581e-02
# FTA_against          -7.450784e-02
# FT_PCT_against       -1.278262e-02
# OREB_against         -5.024207e-02
# DREB_against         -1.102114e-01
# REB_against          -1.181306e-01
# AST_against          -1.670027e-01
# STL_against          -2.352643e-02
# BLK_against          -1.162435e-01
# TOV_against           4.774704e-02
# PF_against            8.331199e-02
# PLUS_MINUS_against   -2.538845e-01
# IS_HOME_against       0.000000e+00
# GAME_ID               2.422015e+07
# SEASON_ID             2.200354e+04
# dtype: float64

# %%
away_means = mirror_df[mirror_df['IS_HOME_for'] == 0].select_dtypes(include='number').mean()
away_means
# Out:
# TEAM_ID_for           1.610613e+09
# MIN_for               8.499655e-05
# PTS_for              -1.363469e-01
# FGM_for              -1.064552e-01
# FGA_for              -1.077243e-02
# FG_PCT_for           -1.089570e-01
# FG3M_for             -1.513854e-02
# FG3A_for              1.113951e-02
# FG3_PCT_for          -3.317327e-02
# FTM_for              -7.412581e-02
# FTA_for              -7.450784e-02
# FT_PCT_for           -1.278262e-02
# OREB_for             -5.024207e-02
# DREB_for             -1.102114e-01
# REB_for              -1.181306e-01
# AST_for              -1.670027e-01
# STL_for              -2.352643e-02
# BLK_for              -1.162435e-01
# TOV_for               4.774704e-02
# PF_for                8.331199e-02
# PLUS_MINUS_for       -2.538845e-01
# IS_HOME_for           0.000000e+00
# TEAM_ID_against       1.610613e+09
# MIN_against          -8.499655e-05
# PTS_against           1.363469e-01
# FGM_against           1.064552e-01
# FGA_against           1.077243e-02
# FG_PCT_against        1.089570e-01
# FG3M_against          1.513854e-02
# FG3A_against         -1.113951e-02
# FG3_PCT_against       3.331437e-02
# FTM_against           7.412581e-02
# FTA_against           7.450784e-02
# FT_PCT_against        1.278262e-02
# OREB_against          5.024425e-02
# DREB_against          1.102162e-01
# REB_against           1.181306e-01
# AST_against           1.670027e-01
# STL_against           2.352643e-02
# BLK_against           1.162435e-01
# TOV_against          -4.774704e-02
# PF_against           -8.331199e-02
# PLUS_MINUS_against    2.538845e-01
# IS_HOME_against       1.000000e+00
# GAME_ID               2.422015e+07
# SEASON_ID             2.200354e+04
# dtype: float64

# %%
home_means - away_means
# Out:
# TEAM_ID_for          -0.009499
# MIN_for              -0.000170
# PTS_for               0.272694
# FGM_for               0.212910
# FGA_for               0.021545
# FG_PCT_for            0.217914
# FG3M_for              0.030277
# FG3A_for             -0.022279
# FG3_PCT_for           0.066488
# FTM_for               0.148252
# FTA_for               0.149016
# FT_PCT_for            0.025565
# OREB_for              0.100486
# DREB_for              0.220428
# REB_for               0.236261
# AST_for               0.334005
# STL_for               0.047053
# BLK_for               0.232487
# TOV_for              -0.095494
# PF_for               -0.166624
# PLUS_MINUS_for        0.507769
# IS_HOME_for           1.000000
# TEAM_ID_against       0.009499
# MIN_against           0.000170
# PTS_against          -0.272694
# FGM_against          -0.212910
# FGA_against          -0.021545
# FG_PCT_against       -0.217914
# FG3M_against         -0.030277
# FG3A_against          0.022279
# FG3_PCT_against      -0.066488
# FTM_against          -0.148252
# FTA_against          -0.149016
# FT_PCT_against       -0.025565
# OREB_against         -0.100486
# DREB_against         -0.220428
# REB_against          -0.236261
# AST_against          -0.334005
# STL_against          -0.047053
# BLK_against          -0.232487
# TOV_against           0.095494
# PF_against            0.166624
# PLUS_MINUS_against   -0.507769
# IS_HOME_against      -1.000000
# GAME_ID               0.000000
# SEASON_ID             0.000000
# dtype: float64

# %%
print(mirror_df['PTS_for'].mean())
print(mirror_df['PTS_for'].std())
# Out:
# 5.392683426763067e-17
# 0.9997835942800289

# %%
(mirror_df['AST_for']).corr(
    mirror_df['WL_for'].map({'W': 1, 'L': 0})
    )
# Out:
# 0.333698957608079

# %%
from sklearn.preprocessing import StandardScaler

# %%
print(streak_df['REB_for_prev_0_A'].corr(streak_df['WL_for_A']))
print(streak_df['REB_against_prev_0_B'].corr(streak_df['WL_for_A']))


print(streak_df['REB_for_prev_0_B'].corr(streak_df['WL_for_A']))
print(streak_df['REB_against_prev_0_B'].corr(streak_df['WL_for_A']))
# Out:
# 0.05844051019090841
# 0.09580767220711606
# -0.05844051019090843
# 0.09580767220711606

# %%
num_home_A = streak_df['k_length_A'] * streak_df['IS_HOME_for_prev_0_A']
num_away_A = streak_df['k_length_A'] * (1 - streak_df['IS_HOME_for_prev_0_A'])
num_home_B = streak_df['k_length_B'] * streak_df['IS_HOME_for_prev_0_B']
num_away_B = streak_df['k_length_B'] * (1 - streak_df['IS_HOME_for_prev_0_B'])

# %%
home_adv_A = num_home_A - num_away_A
home_adv_B = num_home_B - num_away_B

# %%
(streak_df[streak_df['IS_HOME_for_A'] == 1]).select_dtypes(include='number').mean()
# Out:
# SEASON_ID_A                    2.200354e+04
# TEAM_ID_for_A                  1.610613e+09
# WL_for_A                       6.049074e-01
# MIN_for_A                     -3.609371e-04
# PTS_for_A                      1.373358e-01
#                                    ...
# PF_against_prev_0_B            1.200206e-01
# PLUS_MINUS_against_prev_0_B   -6.577712e-03
# IS_HOME_against_prev_0_B       4.877603e-01
# GAME_ID_prev_0_B               2.422116e+07
# k_length_B                     4.015372e+01
# Length: 192, dtype: float64

# %%
streak_cols = [col for col in streak_df.columns if '_0' in col]
print(len(streak_cols))
streak_cols
# Out:
# 94
# ['TEAM_ID_for_prev_0_A',
#  'WL_for_prev_0_A',
#  'MIN_for_prev_0_A',
#  'PTS_for_prev_0_A',
#  'FGM_for_prev_0_A',
#  'FGA_for_prev_0_A',
#  'FG_PCT_for_prev_0_A',
#  'FG3M_for_prev_0_A',
#  'FG3A_for_prev_0_A',
#  'FG3_PCT_for_prev_0_A',
#  'FTM_for_prev_0_A',
#  'FTA_for_prev_0_A',
#  'FT_PCT_for_prev_0_A',
#  'OREB_for_prev_0_A',
#  'DREB_for_prev_0_A',
#  'REB_for_prev_0_A',
#  'AST_for_prev_0_A',
#  'STL_for_prev_0_A',
#  'BLK_for_prev_0_A',
#  'TOV_for_prev_0_A',
#  'PF_for_prev_0_A',
#  'PLUS_MINUS_for_prev_0_A',
#  'IS_HOME_for_prev_0_A',
#  'TEAM_ID_against_prev_0_A',
#  'WL_against_prev_0_A',
#  'MIN_against_prev_0_A',
#  'PTS_against_prev_0_A',
#  'FGM_against_prev_0_A',
#  'FGA_against_prev_0_A',
#  'FG_PCT_against_prev_0_A',
#  'FG3M_against_prev_0_A',
#  'FG3A_against_prev_0_A',
#  'FG3_PCT_against_prev_0_A',
#  'FTM_against_prev_0_A',
#  'FTA_against_prev_0_A',
#  'FT_PCT_against_prev_0_A',
#  'OREB_against_prev_0_A',
#  'DREB_against_prev_0_A',
#  'REB_against_prev_0_A',
#  'AST_against_prev_0_A',
#  'STL_against_prev_0_A',
#  'BLK_against_prev_0_A',
#  'TOV_against_prev_0_A',
#  'PF_against_prev_0_A',
#  'PLUS_MINUS_against_prev_0_A',
#  'IS_HOME_against_prev_0_A',
#  'GAME_ID_prev_0_A',
#  'TEAM_ID_for_prev_0_B',
#  'WL_for_prev_0_B',
#  'MIN_for_prev_0_B',
#  'PTS_for_prev_0_B',
#  'FGM_for_prev_0_B',
#  'FGA_for_prev_0_B',
#  'FG_PCT_for_prev_0_B',
#  'FG3M_for_prev_0_B',
#  'FG3A_for_prev_0_B',
#  'FG3_PCT_for_prev_0_B',
#  'FTM_for_prev_0_B',
#  'FTA_for_prev_0_B',
#  'FT_PCT_for_prev_0_B',
#  'OREB_for_prev_0_B',
#  'DREB_for_prev_0_B',
#  'REB_for_prev_0_B',
#  'AST_for_prev_0_B',
#  'STL_for_prev_0_B',
#  'BLK_for_prev_0_B',
#  'TOV_for_prev_0_B',
#  'PF_for_prev_0_B',
#  'PLUS_MINUS_for_prev_0_B',
#  'IS_HOME_for_prev_0_B',
#  'TEAM_ID_against_prev_0_B',
#  'WL_against_prev_0_B',
#  'MIN_against_prev_0_B',
#  'PTS_against_prev_0_B',
#  'FGM_against_prev_0_B',
#  'FGA_against_prev_0_B',
#  'FG_PCT_against_prev_0_B',
#  'FG3M_against_prev_0_B',
#  'FG3A_against_prev_0_B',
#  'FG3_PCT_against_prev_0_B',
#  'FTM_against_prev_0_B',
#  'FTA_against_prev_0_B',
#  'FT_PCT_against_prev_0_B',
#  'OREB_against_prev_0_B',
#  'DREB_against_prev_0_B',
#  'REB_against_prev_0_B',
#  'AST_against_prev_0_B',
#  'STL_against_prev_0_B',
#  'BLK_against_prev_0_B',
#  'TOV_against_prev_0_B',
#  'PF_against_prev_0_B',
#  'PLUS_MINUS_against_prev_0_B',
#  'IS_HOME_against_prev_0_B',
#  'GAME_ID_prev_0_B']

# %%
non_streak_cols = [col for col in streak_df.columns if '_0' not in col]
print(len(non_streak_cols))
non_streak_cols
# Out:
# 112
# ['SEASON_ID_A',
#  'GAME_DATE_A',
#  'TEAM_ABBREVIATION_for_A',
#  'TEAM_ABBREVIATION_against_A',
#  'TEAM_NAME_for_A',
#  'TEAM_NAME_against_A',
#  'MATCHUP_for_A',
#  'MATCHUP_against_A',
#  'TEAM_ID_for_A',
#  'WL_for_A',
#  'MIN_for_A',
#  'PTS_for_A',
#  'FGM_for_A',
#  'FGA_for_A',
#  'FG_PCT_for_A',
#  'FG3M_for_A',
#  'FG3A_for_A',
#  'FG3_PCT_for_A',
#  'FTM_for_A',
#  'FTA_for_A',
#  'FT_PCT_for_A',
#  'OREB_for_A',
#  'DREB_for_A',
#  'REB_for_A',
#  'AST_for_A',
#  'STL_for_A',
#  'BLK_for_A',
#  'TOV_for_A',
#  'PF_for_A',
#  'PLUS_MINUS_for_A',
#  'IS_HOME_for_A',
#  'TEAM_ID_against_A',
#  'WL_against_A',
#  'MIN_against_A',
#  'PTS_against_A',
#  'FGM_against_A',
#  'FGA_against_A',
#  'FG_PCT_against_A',
#  'FG3M_against_A',
#  'FG3A_against_A',
#  'FG3_PCT_against_A',
#  'FTM_against_A',
#  'FTA_against_A',
#  'FT_PCT_against_A',
#  'OREB_against_A',
#  'DREB_against_A',
#  'REB_against_A',
#  'AST_against_A',
#  'STL_against_A',
#  'BLK_against_A',
#  'TOV_against_A',
#  'PF_against_A',
#  'PLUS_MINUS_against_A',
#  'IS_HOME_against_A',
#  'GAME_ID_A',
#  'k_length_A',
#  'SEASON_ID_B',
#  'GAME_DATE_B',
#  'TEAM_ABBREVIATION_for_B',
#  'TEAM_ABBREVIATION_against_B',
#  'TEAM_NAME_for_B',
#  'TEAM_NAME_against_B',
#  'MATCHUP_for_B',
#  'MATCHUP_against_B',
#  'TEAM_ID_for_B',
#  'WL_for_B',
#  'MIN_for_B',
#  'PTS_for_B',
#  'FGM_for_B',
#  'FGA_for_B',
#  'FG_PCT_for_B',
#  'FG3M_for_B',
#  'FG3A_for_B',
#  'FG3_PCT_for_B',
#  'FTM_for_B',
#  'FTA_for_B',
#  'FT_PCT_for_B',
#  'OREB_for_B',
#  'DREB_for_B',
#  'REB_for_B',
#  'AST_for_B',
#  'STL_for_B',
#  'BLK_for_B',
#  'TOV_for_B',
#  'PF_for_B',
#  'PLUS_MINUS_for_B',
#  'IS_HOME_for_B',
#  'TEAM_ID_against_B',
#  'WL_against_B',
#  'MIN_against_B',
#  'PTS_against_B',
#  'FGM_against_B',
#  'FGA_against_B',
#  'FG_PCT_against_B',
#  'FG3M_against_B',
#  'FG3A_against_B',
#  'FG3_PCT_against_B',
#  'FTM_against_B',
#  'FTA_against_B',
#  'FT_PCT_against_B',
#  'OREB_against_B',
#  'DREB_against_B',
#  'REB_against_B',
#  'AST_against_B',
#  'STL_against_B',
#  'BLK_against_B',
#  'TOV_against_B',
#  'PF_against_B',
#  'PLUS_MINUS_against_B',
#  'IS_HOME_against_B',
#  'GAME_ID_B',
#  'k_length_B']

# %%
streak_features = streak_df[streak_cols].sort_index(axis=1)
non_streak_features = streak_df[non_streak_cols].sort_index(axis=1)

# %%
non_streak_features[non_streak_features['IS_HOME_for_A'] == 1].mean()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[155], line 1
# ----> 1 non_streak_features[non_streak_features['IS_HOME_for_A'] == 1].mean()
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/frame.py:10519, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   10515     df = df.T
#   10517 # After possibly _get_data and transposing, we are now in the
#   10518 #  simple case where we can use BlockManager.reduce
# > 10519 res = df._mgr.reduce(blk_func)
#   10520 out = df._constructor(res).iloc[0]
#   10521 if out_dtype is not None:
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/internals/managers.py:1534, in BlockManager.reduce(self, func)
#    1532 res_blocks: list[Block] = []
#    1533 for blk in self.blocks:
# -> 1534     nbs = blk.reduce(func)
#    1535     res_blocks.extend(nbs)
#    1537 index = Index([None])  # placeholder
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/internals/blocks.py:339, in Block.reduce(self, func)
#     333 @final
#     334 def reduce(self, func) -> list[Block]:
#     335     # We will apply the function and reshape the result into a single-row
#     336     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     337     assert self.ndim == 2
# --> 339     result = func(self.values)
#     341     if self.values.ndim == 1:
#     342         # TODO(EA2D): special case not needed with 2D EAs
#     343         res_values = np.array([[result]])
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/frame.py:10482, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   10480     return values._reduce(name, skipna=skipna, **kwds)
#   10481 else:
# > 10482     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/pandas/core/nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File /opt/anaconda3/envs/my_env/lib/python3.8/site-packages/numpy/core/_methods.py:48, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      46 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      47          initial=_NoValue, where=True):
# ---> 48     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# KeyboardInterrupt:
